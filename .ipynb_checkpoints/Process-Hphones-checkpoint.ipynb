# %%
# %matplotlib inline

# %%
import Signal
import random
import matplotlib.pyplot as plt
import math
import numpy as np
import scipy.signal as sig
from scipy.signal import freqz, butter, lfilter
from itertools import cycle, islice

# %% [markdown]
# ## Generate Signal

# %%
def graph_signals(times, arrays, timestart=0, dur=2):
    color_opts = ['b-', 'r-', 'g-', 'y-', 'o-', 'p-']
    plot_data = []
    if(isinstance(arrays[0], list)):
        colors = list(islice(cycle(color_opts), len(arrays)))
        for i in range(len(arrays)):
            plot_data.extend([times, arrays[i], colors[i]])
    else:
        plot_data.extend([times, arrays, color_opts[0]])
    plt.figure(figsize=(20,10))
    plt.grid(True)
    plt.plot(*plot_data)
    plt.xlabel('Time (s)')
    plt.ylabel('Charge (arbitrary)')
    plt.show()

# %%
random.seed(987)
d = .1 #m
angle = 1.8 #rad
coords = [[0.005, 0.005], [0.005, -0.005], [-0.005, -0.005], [-0.005, 0.005]]
freq = 45 #kHz
sos = 1.5 #m/ms (MAY NEED TO BE CALIBRATED)
sr = 1000 #kHz
read = 2000 #ms
noise = 0.5 #standard deviation
time_on = 100 #ms --ping duration
ping_period = 2000 #ms
ping_start = random.randint(0, read*500)/1000.0

#create an array containing the simulated readings arrays of each sensor
signals = []
for i in range(len(coords)):
    signals.append(Signal.Signal(d, angle, coords[i], freq, sos, sr, read, noise, time_on, ping_period, ping_start).signals)

times = np.linspace(0, read/1000, len(signals[0]))
# Out:
# 558.6973025987511
# 558.7037139770109
# 558.7022712720195
# 558.6957125728115

# %%
def find_start(signal, times, sr):
    #thresholds: NEED TO BE CALIBRATED!
    amp_thresh = 1.8
    ave_thresh = 0.5
    freq_thresh = 0.2

    check_time = 10 #ms
    stft_time = 1 #ms

    for i, sample in enumerate(signal):
        #check if sample is above amplitude threshold
        if sample > amp_thresh and times[i] + check_time / 1000.0 < times[-1]:
            ave = math.fsum(map(abs, signal[i:i+sr*check_time])) / float(sr * check_time)
            #check if the average for the next 10 ms is above average threshold
            if ave > ave_thresh:
                #check if aplitude at frequency is above frequency threshold
                f, t, Zxx = sig.stft(signal[i:i+sr*stft_time], fs=sr*1000, nperseg=50, nfft=200)
                for j, freq_amp in enumerate(Zxx[list(f).index(freq*1000)]):
                #for j, freq_amp in enumerate(bandpassFilter(signal[i:i+sr*stft_time])):
                    if abs(freq_amp) > freq_thresh:
                        print((times[i] + t[j]) * 1000)
                        return times[i] + t[j]
                        #return times[i + j]
    return 0

# %%
sig_starts = []

for item in signals:
    sig_starts.append(find_start(item, times, sr))

timestart = sig_starts[0]
dur = 0.001

timeIdx = int(timestart*sr*1000)
durIdx = int(dur*sr*1000)

short_signals = []
for item in signals:
    short_signals.append([times[timeIdx:timeIdx+durIdx], item[timeIdx:timeIdx+durIdx]])

graph_signals(*short_signals[0], timestart, dur)
# Out:
# 558.9182794591397
# 558.7592793796397
# 558.7192789346394
# 558.6932791466395

# %%
graph_signals(times, signals)

# %% [markdown]
# ## Signal Processing

# %%
def butter_bandpass(lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a

# %%
def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = lfilter(b, a, data)
    return y

# %%
def bandpassFilter(signal):
    diff = freq*.1
    lowcut = (freq-diff)*1000
    highcut = (freq+diff)*1000
    y = butter_bandpass_filter(signal, lowcut, highcut, sr*1000, order=2)
    return y

# %%
filtered_signals = []
for signal in short_signals:
    filtered_signals.append((signal[0], bandpassFilter(signal[1])))

# %%
plt.figure(figsize = (20,10))
plt.plot(filtered_signals[0][0], filtered_signals[0][1], label='Filtered signal (%g Hz)')
plt.xlabel('time (seconds)')
plt.grid(True)
plt.axis('tight')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## STFT

# %%
f, t, Zxx = sig.stft(short_signals[0][1], fs=sr*1000, nperseg=50, nfft=200)
plt.figure(figsize=(20,10))
f = np.array(f)
idx = np.where(f == freq*1000)
plt.pcolormesh(t+timestart, f, np.abs(Zxx))
plt.title('STFT Magnitude')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()
print(f, idx[0],freq*1000)
# Out:
# [     0.   5000.  10000.  15000.  20000.  25000.  30000.  35000.  40000.
#   45000.  50000.  55000.  60000.  65000.  70000.  75000.  80000.  85000.
#   90000.  95000. 100000. 105000. 110000. 115000. 120000. 125000. 130000.
#  135000. 140000. 145000. 150000. 155000. 160000. 165000. 170000. 175000.
#  180000. 185000. 190000. 195000. 200000. 205000. 210000. 215000. 220000.
#  225000. 230000. 235000. 240000. 245000. 250000. 255000. 260000. 265000.
#  270000. 275000. 280000. 285000. 290000. 295000. 300000. 305000. 310000.
#  315000. 320000. 325000. 330000. 335000. 340000. 345000. 350000. 355000.
#  360000. 365000. 370000. 375000. 380000. 385000. 390000. 395000. 400000.
#  405000. 410000. 415000. 420000. 425000. 430000. 435000. 440000. 445000.
#  450000. 455000. 460000. 465000. 470000. 475000. 480000. 485000. 490000.
#  495000. 500000.] [9] 45000

# %%
plt.figure(figsize=(20,10))
plt.plot(t+timestart, np.abs(Zxx[idx][0]))
plt.show()
